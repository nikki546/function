# %% [markdown]
# **Theory** **Answers**

# %%
'''1. What is the difference between a function and a method in Python?

Function: A block of code that performs a specific task and is defined using def keyword.

Method: A function that is associated with an object and is called using dot notation.

Example:

# Function
def add(a, b):
    return a + b

# Method
text = "hello"
print(text.upper())  # upper() is a string method
'''

# %%
'''2. Explain the concept of function arguments and parameters in Python.

Parameters are variables listed inside parentheses in the function definition.

Arguments are the actual values passed when calling a function.

Example:'''

def greet(name):  # name = parameter
    print("Hello", name)

greet("Alice")  # "Alice" = argument
# Out:
# Hello Alice

# %%
'''3. What are the different ways to define and call a function in Python?

Ways to define: Using def or lambda.
Ways to call: Directly by function name or through another function.

Example:'''

def square(x):
    return x * x

print(square(4))        # Normal call
result = (lambda x: x*x)(5)  # Lambda function
print(result)
# Out:
# 16
# 25

# %%
'''4. What is the purpose of the return statement in a Python function?

The return statement sends the result back to the caller and ends the function execution.

Example:'''

def add(a, b):
    return a + b

sum_result = add(5, 3)
print(sum_result)
# Out:
# 8

# %%
'''5. What are iterators in Python and how do they differ from iterables?

Iterable: An object capable of returning its elements (like list, tuple, string).

Iterator: An object that is used to iterate over an iterable, one element at a time.

Example:'''

numbers = [1, 2, 3]
it = iter(numbers)  # iterator
print(next(it))  # 1
print(next(it))  # 2
# Out:
# 1
# 2

# %%
'''6. Explain the concept of generators in Python and how they are defined.

Generators are functions that yield one item at a time instead of returning all items at once. Defined using yield.

Example:'''

def countdown(n):
    while n > 0:
        yield n
        n -= 1

for val in countdown(3):
    print(val)
# Out:
# 3
# 2
# 1

# %%
'''7. What are the advantages of using generators over regular functions?

-Save memory (generate items one at a time)
-Faster for large data
-Lazy evaluation (compute only when needed)'''

# %%
'''8. What is a lambda function in Python and when is it typically used?

A lambda is an anonymous (nameless) one-line function, often used for short operations or with functions like map, filter.'''

# %%
'''10. What is the difference between map(), reduce(), and filter() functions in Python?
| Function     | Purpose                                | Example                                   |
| ------------ | -------------------------------------- | ----------------------------------------- |
| **map()**    | Applies a function to all elements     | `map(lambda x: x*2, [1,2,3])` → `[2,4,6]` |
| **filter()** | Filters elements based on condition    | `filter(lambda x: x>2, [1,2,3])` → `[3]`  |
| **reduce()** | Reduces all elements to a single value | `reduce(lambda x,y: x+y, [1,2,3])` → `6`  |
'''

# %%
'''11. Using pen & paper write the internal mechanism for sum operation using reduce() function on list [47, 11, 42, 13].
The reduce() function in Python applies a given function cumulatively to the items of a list (or any iterable), from left to right, so as to reduce the list to a single value.
When performing a sum operation using reduce(), the internal mechanism works step by step by taking two elements at a time and applying the lambda function.
Concept:'''
reduce(lambda x, y: x + y, [47, 11, 42, 13])

# %% [markdown]
# ![20251101_054131461_iOS(1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Practical Questions

# %%
'''Q1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.'''
def sum_even(numbers):
    total = 0
    for n in numbers:
        if n % 2 == 0:
            total += n
    return total

# %%
'''Q2. Create a Python function that accepts a string and returns the reverse of that string.'''

def reverse_string(s):
    return s[::-1]

# %%
'''Q3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.'''

def square_list(numbers):
    return [n**2 for n in numbers]

# %%
'''Q4. Write a Python function that checks if a given number is prime or not from 1 to 200.'''

def is_prime(num):
    if num < 2:
        return False
    for i in range(2,n):
        if num % i == 0:
            return False
    return True

# %%
'''Q5.Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.'''
# Iterator class for Fibonacci Sequence
class Fibonacci:
    def __init__(self, n):
        self.n = n
        self.a = 0
        self.b = 1
        self.count = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count < self.n:
            value = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return value
        else:
            raise StopIteration

# Create object and display Fibonacci sequence
fib = Fibonacci(7)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %%
'''Q6.Write a generator function in Python that yields the powers of 2 up to a given exponent.'''

def power_of_two(limit):
    for i in range(limit + 1):
        yield 2 ** i

# %%
'''Q7.Implement a generator function that reads a file line by line and yields each line as a string.'''

def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()

# %%
'''Q8.Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.'''

data = [(1, 4), (2, 1), (3, 3)]
sorted_data = sorted(data, key=lambda x: x[1])

# %%
'''Q9.Write a Python program that uses map() to convert a list of temperatures from Celsius to Fahrenheit.'''

celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)
# Out:
# [32.0, 68.0, 98.6, 212.0]

# %%
'''Q10.Create a Python program that uses filter() to remove all the vowels from a given string.'''

string = "Hello World"
vowels = "aeiouAEIOU"
result = ''.join(filter(lambda ch: ch not in vowels, string))
print(result)
# Out:
# Hll Wrld

# %%
'''Q11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

Order Number | Book Title and Author | Quantity | Price per Item
34587        | Learning Python, Mark Lutz         | 4 | 40.95
98762        | Programming Python, Mark Lutz      | 5 | 56.80
77226        | Head First Python, Paul Barry      | 3 | 32.95
88112        | Einführung in Python3, Bernd Klein | 3 | 24.99


Write a Python program that returns a list with 2-tuples.
Each tuple consists of the order number and the product of the price per item and the quantity.
The product should be increased by 10.0 € if the value of the order is smaller than 100.0 €.

Write the Python program using lambda and map().'''

# Given list of book orders
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Using lambda and map to calculate total cost
result = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10), orders))

# Display result
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
